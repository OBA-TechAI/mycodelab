# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
import pandas as pd

fPath1 = r"\\ad.uws.edu.au\dfshare\HomesBLK$\90960046\My Documents\mycodelab\outputs-20260805T024105Z-1-001\outputs"

df = pd.read_parquet(fPath1 + r"\cohort_labels.parquet")
df.head(20)
# Out:
#     subject_id  index_hadm_id     index_admittime     index_dischtime  \
# 0     10000635       26134563 2136-06-19 14:24:00 2136-06-20 11:30:00
# 1     10000980       29654838 2188-01-03 17:41:00 2188-01-05 17:30:00
# 2     10001176       23334588 2186-11-29 03:56:00 2186-12-02 15:00:00
# 3     10001843       21728396 2131-11-09 16:05:00 2131-11-11 11:23:00
# 4     10001877       25679292 2149-05-21 15:53:00 2149-05-27 13:35:00
# 5     10002013       28603984 2156-06-28 15:53:00 2156-07-02 15:39:00
# 6     10002221       21008195 2200-09-29 17:28:00 2200-10-01 14:58:00
# 7     10002443       21329021 2183-10-17 23:20:00 2183-10-20 18:47:00
# 8     10002495       24982426 2141-05-22 20:17:00 2141-05-29 17:41:00
# 9     10002976       27179825 2145-02-28 19:44:00 2145-03-05 16:45:00
# 10    10003299       21743184 2173-05-12 12:29:00 2173-05-13 18:00:00
# 11    10004322       28755331 2131-01-23 21:30:00 2131-01-26 17:40:00
# ...

# %%
df.shape
# Out:
# (46312, 21)

# %%
list(df.columns)
# Out:
# ['subject_id',
#  'index_hadm_id',
#  'index_admittime',
#  'index_dischtime',
#  'deathtime',
#  'admission_type',
#  'discharge_location',
#  'race',
#  'insurance',
#  'gender',
#  'age_at_admission',
#  'n_eligible_admissions',
#  'type2_only_flag',
#  'index_los_days',
#  'primary_icd_dn_label',
#  'secondary_lab_proxy_label',
#  'strict_sensitivity_label',
#  'esrd_or_dialysis_flag',
#  'max_creatinine',
#  'max_bun',
#  'split']

# %%
import pandas as pd

fPath1 = r"\\ad.uws.edu.au\dfshare\HomesBLK$\90960046\My Documents\mycodelab\outputs-20260805T024105Z-1-001\outputs"

df1 = pd.read_parquet(fPath1 + r"\dx_sequences.parquet")
df1.head(20)
# Out:
#     subject_id   hadm_id  visit_number  age_at_visit  days_since_prev_visit  \
# 0     10000635  26134563             1            74                   <NA>
# 1     10000635  26134563             1            74                   <NA>
# 2     10000635  26134563             1            74                   <NA>
# 3     10000980  29654838             1            75                   <NA>
# 4     10000980  29654838             1            75                   <NA>
# 5     10000980  29654838             1            75                   <NA>
# 6     10000980  29654838             1            75                   <NA>
# 7     10000980  29654838             1            75                   <NA>
# 8     10000980  29654838             1            75                   <NA>
# 9     10000980  29654838             1            75                   <NA>
# 10    10000980  29654838             1            75                   <NA>
# ...

# %%
print(df1.days_since_prev_visit.value_counts())
# Out:
# Series([], Name: count, dtype: Int64)

# %%
print(df1.split.value_counts())
# Out:
# split
# train         415469
# validation     90420
# test           90238
# Name: count, dtype: int64

# %%
df1.shape
# Out:
# (596127, 9)
